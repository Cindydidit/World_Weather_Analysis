# %%
# Import dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
#lats = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
#lngs = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
#lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the print() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(coordinate[0], coordinate[1])

# %%
# Use the print() function to display the latitude and longitude combinations.
#for coordinate in coordinates:
    #print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          #citipy.nearest_city(coordinate[0], coordinate[1]).country_code)

# %%
# Import citipy
from citipy import citipy

# %%
# Create a list to store city names.
cities = []
# Iterate through the coordinates()
for coordinate in coordinates:
    # Retrieve the nearest city using the latitude and longitude pair.
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is not in cities[]...
    if city not in cities:
        # Add it to the cities list.
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 645

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters to start at 1.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    #if (i % 50 == 0 and i >= 50):
        #set_count += 1
        #record_count = 1
        # 60 second pause to prevent time-out errors.
        #time.sleep(60)

    # Create endpoint URL with each city.
    #city_url = url + "&q=" + cities[i]
    # Iterate through the list of cities and retrieve both the index, and the city from the list.    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # If the remainder of the index divided by 50 is equal to 0 and greater than 50.
    if (i % 50 == 0 and i >= 50):
        # Increment set_count by 1.
        set_count += 1
        # Increment record_count by 1.
        record_count = 1
        # 60 second pause to prevent time-out errors.
        time.sleep(60)

    # Create endpoint URL with each city.
    # Remove the blank spaces in the city name and concatenate the city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
        
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        #Assign variables for each piece of data we need.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list in a dictionary format.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ribeira grande
# Processing Record 2 of Set 1 | portland
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | centralia
# Processing Record 5 of Set 1 | vao
# Processing Record 6 of Set 1 | san mateo ixtatan
# Processing Record 7 of Set 1 | sept-iles
# Processing Record 8 of Set 1 | kunming
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 1 | mount isa
# Processing Record 12 of Set 1 | cabo san lucas
# Processing Record 13 of Set 1 | tupik
# Processing Record 14 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | norman wells
# Processing Record 17 of Set 1 | hilo
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | gizo
# Processing Record 21 of Set 1 | tilichiki
# Processing Record 22 of Set 1 | castro
# Processing Record 23 of Set 1 | busselton
# Processing Record 24 of Set 1 | amahai
# Processing Record 25 of Set 1 | shamkhal
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | puerto ayora
# Processing Record 28 of Set 1 | saldanha
# Processing Record 29 of Set 1 | plettenberg bay
# Processing Record 30 of Set 1 | bluff
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | yulara
# Processing Record 34 of Set 1 | mar del plata
# Processing Record 35 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 1 | bethel
# Processing Record 37 of Set 1 | constitucion
# Processing Record 38 of Set 1 | teya
# Processing Record 39 of Set 1 | hobart
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | lagunas
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | zhangjiakou
# Processing Record 44 of Set 1 | avarua
# Processing Record 45 of Set 1 | conde
# Processing Record 46 of Set 1 | fairbanks
# Processing Record 47 of Set 1 | port alfred
# Processing Record 48 of Set 1 | maningrida
# Processing Record 49 of Set 1 | saint anthony
# Processing Record 50 of Set 1 | oxapampa
# Processing Record 1 of Set 2 | palembang
# Processing Record 2 of Set 2 | fortuna
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | mashhad
# Processing Record 5 of Set 2 | turukhansk
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | cap malheureux
# Processing Record 8 of Set 2 | sur
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | nusaybin
# Processing Record 11 of Set 2 | azul
# Processing Record 12 of Set 2 | narsaq
# Processing Record 13 of Set 2 | pimentel
# Processing Record 14 of Set 2 | upernavik
# Processing Record 15 of Set 2 | denia
# Processing Record 16 of Set 2 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 17 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 2 | christchurch
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | awjilah
# Processing Record 22 of Set 2 | trelew
# Processing Record 23 of Set 2 | juneau
# Processing Record 24 of Set 2 | cherskiy
# Processing Record 25 of Set 2 | prachuap khiri khan
# Processing Record 26 of Set 2 | chara
# Processing Record 27 of Set 2 | tessalit
# Processing Record 28 of Set 2 | raudeberg
# Processing Record 29 of Set 2 | shenjiamen
# Processing Record 30 of Set 2 | iqaluit
# Processing Record 31 of Set 2 | ufimskiy
# Processing Record 32 of Set 2 | acapulco
# Processing Record 33 of Set 2 | chokurdakh
# Processing Record 34 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | pevek
# Processing Record 37 of Set 2 | longyearbyen
# Processing Record 38 of Set 2 | sisak
# Processing Record 39 of Set 2 | nikolskoye
# Processing Record 40 of Set 2 | saint-philippe
# Processing Record 41 of Set 2 | naze
# Processing Record 42 of Set 2 | nome
# Processing Record 43 of Set 2 | svetlogorsk
# Processing Record 44 of Set 2 | byron bay
# Processing Record 45 of Set 2 | atuona
# Processing Record 46 of Set 2 | emerald
# Processing Record 47 of Set 2 | pochutla
# Processing Record 48 of Set 2 | jumla
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | havelock
# Processing Record 1 of Set 3 | roald
# Processing Record 2 of Set 3 | bambous virieux
# Processing Record 3 of Set 3 | hithadhoo
# Processing Record 4 of Set 3 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 5 of Set 3 | kloulklubed
# Processing Record 6 of Set 3 | carnarvon
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | airai
# Processing Record 9 of Set 3 | petlawad
# Processing Record 10 of Set 3 | bonavista
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | tiksi
# Processing Record 13 of Set 3 | san policarpo
# Processing Record 14 of Set 3 | progreso
# Processing Record 15 of Set 3 | ambulu
# Processing Record 16 of Set 3 | mugur-aksy
# Processing Record 17 of Set 3 | calama
# Processing Record 18 of Set 3 | barrow
# Processing Record 19 of Set 3 | batagay-alyta
# Processing Record 20 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 3 | bilma
# Processing Record 22 of Set 3 | viedma
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | linjiang
# Processing Record 25 of Set 3 | esperance
# Processing Record 26 of Set 3 | nidadavole
# Processing Record 27 of Set 3 | campos belos
# Processing Record 28 of Set 3 | bolshaya martynovka
# Processing Record 29 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 30 of Set 3 | ahipara
# Processing Record 31 of Set 3 | agva
# City not found. Skipping...
# Processing Record 32 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 3 | coihaique
# Processing Record 34 of Set 3 | kodiak
# Processing Record 35 of Set 3 | butaritari
# Processing Record 36 of Set 3 | necochea
# Processing Record 37 of Set 3 | akmene
# Processing Record 38 of Set 3 | noyabrsk
# Processing Record 39 of Set 3 | timra
# Processing Record 40 of Set 3 | provideniya
# Processing Record 41 of Set 3 | komsomolskiy
# Processing Record 42 of Set 3 | blackfoot
# Processing Record 43 of Set 3 | monrovia
# Processing Record 44 of Set 3 | kamenka
# Processing Record 45 of Set 3 | mayfield
# Processing Record 46 of Set 3 | camana
# Processing Record 47 of Set 3 | alice springs
# Processing Record 48 of Set 3 | kirakira
# Processing Record 49 of Set 3 | ixtapa
# Processing Record 50 of Set 3 | port lincoln
# Processing Record 1 of Set 4 | new norfolk
# Processing Record 2 of Set 4 | nichlaul
# Processing Record 3 of Set 4 | fernie
# Processing Record 4 of Set 4 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 4 | esil
# Processing Record 6 of Set 4 | amapa
# Processing Record 7 of Set 4 | adrar
# Processing Record 8 of Set 4 | vestmannaeyjar
# Processing Record 9 of Set 4 | georgetown
# Processing Record 10 of Set 4 | klaksvik
# Processing Record 11 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 4 | kapaa
# Processing Record 13 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 14 of Set 4 | lavrentiya
# Processing Record 15 of Set 4 | coahuayana
# Processing Record 16 of Set 4 | alofi
# Processing Record 17 of Set 4 | lebu
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | sedan
# Processing Record 20 of Set 4 | lima
# Processing Record 21 of Set 4 | sitka
# Processing Record 22 of Set 4 | pedasi
# Processing Record 23 of Set 4 | plaisir
# Processing Record 24 of Set 4 | olinda
# Processing Record 25 of Set 4 | achit
# Processing Record 26 of Set 4 | vila franca do campo
# Processing Record 27 of Set 4 | polunochnoye
# Processing Record 28 of Set 4 | tucano
# Processing Record 29 of Set 4 | dikson
# Processing Record 30 of Set 4 | pitimbu
# Processing Record 31 of Set 4 | nan
# Processing Record 32 of Set 4 | miles city
# Processing Record 33 of Set 4 | tuatapere
# Processing Record 34 of Set 4 | bure
# Processing Record 35 of Set 4 | san rafael
# Processing Record 36 of Set 4 | meulaboh
# Processing Record 37 of Set 4 | eirunepe
# Processing Record 38 of Set 4 | moncao
# Processing Record 39 of Set 4 | sovetskiy
# Processing Record 40 of Set 4 | rochegda
# Processing Record 41 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 4 | gat
# Processing Record 43 of Set 4 | abejorral
# Processing Record 44 of Set 4 | svetlyy
# Processing Record 45 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 4 | mitsamiouli
# Processing Record 47 of Set 4 | mumbwa
# Processing Record 48 of Set 4 | almas
# Processing Record 49 of Set 4 | hambantota
# Processing Record 50 of Set 4 | arraial do cabo
# Processing Record 1 of Set 5 | rajshahi
# Processing Record 2 of Set 5 | nizhniy baskunchak
# Processing Record 3 of Set 5 | sao felix do xingu
# Processing Record 4 of Set 5 | pafos
# Processing Record 5 of Set 5 | nuuk
# Processing Record 6 of Set 5 | khatanga
# Processing Record 7 of Set 5 | along
# Processing Record 8 of Set 5 | milkovo
# Processing Record 9 of Set 5 | general roca
# Processing Record 10 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 5 | port augusta
# Processing Record 12 of Set 5 | tasiilaq
# Processing Record 13 of Set 5 | kaspiyskiy
# Processing Record 14 of Set 5 | liancheng
# Processing Record 15 of Set 5 | santa fe
# Processing Record 16 of Set 5 | bodden town
# Processing Record 17 of Set 5 | goya
# Processing Record 18 of Set 5 | broome
# Processing Record 19 of Set 5 | cidreira
# Processing Record 20 of Set 5 | masvingo
# Processing Record 21 of Set 5 | man
# Processing Record 22 of Set 5 | acarau
# Processing Record 23 of Set 5 | mount gambier
# Processing Record 24 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 5 | touros
# Processing Record 26 of Set 5 | kaardi
# City not found. Skipping...
# Processing Record 27 of Set 5 | charters towers
# Processing Record 28 of Set 5 | bacuit
# City not found. Skipping...
# Processing Record 29 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 5 | dunedin
# Processing Record 31 of Set 5 | zyryanka
# Processing Record 32 of Set 5 | asfi
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | nybro
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | puerto narino
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | mossendjo
# Processing Record 39 of Set 5 | east london
# Processing Record 40 of Set 5 | lasa
# Processing Record 41 of Set 5 | kirovskiy
# Processing Record 42 of Set 5 | san patricio
# Processing Record 43 of Set 5 | sayyan
# Processing Record 44 of Set 5 | sambava
# Processing Record 45 of Set 5 | porbandar
# Processing Record 46 of Set 5 | huanren
# Processing Record 47 of Set 5 | port elizabeth
# Processing Record 48 of Set 5 | semnan
# Processing Record 49 of Set 5 | zhuhai
# Processing Record 50 of Set 5 | mountain home
# Processing Record 1 of Set 6 | cape town
# Processing Record 2 of Set 6 | mordovo
# Processing Record 3 of Set 6 | itarema
# Processing Record 4 of Set 6 | belyy
# Processing Record 5 of Set 6 | hamilton
# Processing Record 6 of Set 6 | maanshan
# Processing Record 7 of Set 6 | port macquarie
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | rocha
# Processing Record 11 of Set 6 | nantucket
# Processing Record 12 of Set 6 | bambanglipuro
# Processing Record 13 of Set 6 | mayo
# Processing Record 14 of Set 6 | port-gentil
# Processing Record 15 of Set 6 | sal rei
# Processing Record 16 of Set 6 | vung tau
# Processing Record 17 of Set 6 | chippewa falls
# Processing Record 18 of Set 6 | tiznit
# Processing Record 19 of Set 6 | san luis
# Processing Record 20 of Set 6 | springdale
# Processing Record 21 of Set 6 | yenagoa
# Processing Record 22 of Set 6 | xuddur
# Processing Record 23 of Set 6 | antalaha
# Processing Record 24 of Set 6 | kieta
# Processing Record 25 of Set 6 | henties bay
# Processing Record 26 of Set 6 | hilton head island
# Processing Record 27 of Set 6 | labuhan
# Processing Record 28 of Set 6 | portree
# Processing Record 29 of Set 6 | luziania
# Processing Record 30 of Set 6 | brae
# Processing Record 31 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 32 of Set 6 | zhigansk
# Processing Record 33 of Set 6 | astana
# Processing Record 34 of Set 6 | husavik
# Processing Record 35 of Set 6 | shingu
# Processing Record 36 of Set 6 | evanton
# Processing Record 37 of Set 6 | ancud
# Processing Record 38 of Set 6 | komsomolets
# Processing Record 39 of Set 6 | isangel
# Processing Record 40 of Set 6 | ilula
# Processing Record 41 of Set 6 | sobolevo
# Processing Record 42 of Set 6 | vuktyl
# Processing Record 43 of Set 6 | severnyy
# Processing Record 44 of Set 6 | guerrero negro
# Processing Record 45 of Set 6 | kavieng
# Processing Record 46 of Set 6 | council bluffs
# Processing Record 47 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 48 of Set 6 | quthing
# Processing Record 49 of Set 6 | coquimbo
# Processing Record 50 of Set 6 | victoria
# Processing Record 1 of Set 7 | kungurtug
# Processing Record 2 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 3 of Set 7 | dingle
# Processing Record 4 of Set 7 | samarai
# Processing Record 5 of Set 7 | stornoway
# Processing Record 6 of Set 7 | nisia floresta
# Processing Record 7 of Set 7 | liwale
# Processing Record 8 of Set 7 | erenhot
# Processing Record 9 of Set 7 | jabiru
# City not found. Skipping...
# Processing Record 10 of Set 7 | ca mau
# Processing Record 11 of Set 7 | mehamn
# Processing Record 12 of Set 7 | gold coast
# Processing Record 13 of Set 7 | burgeo
# Processing Record 14 of Set 7 | guia de isora
# Processing Record 15 of Set 7 | kamaishi
# Processing Record 16 of Set 7 | wajid
# Processing Record 17 of Set 7 | eyl
# Processing Record 18 of Set 7 | kangasala
# Processing Record 19 of Set 7 | kapoeta
# Processing Record 20 of Set 7 | cochrane
# Processing Record 21 of Set 7 | chuy
# Processing Record 22 of Set 7 | bambari
# Processing Record 23 of Set 7 | umm durman
# City not found. Skipping...
# Processing Record 24 of Set 7 | vila velha
# Processing Record 25 of Set 7 | changping
# Processing Record 26 of Set 7 | saint-augustin
# Processing Record 27 of Set 7 | diamantino
# Processing Record 28 of Set 7 | karratha
# Processing Record 29 of Set 7 | dunmore town
# Processing Record 30 of Set 7 | nurota
# Processing Record 31 of Set 7 | katsuura
# Processing Record 32 of Set 7 | rio grande
# Processing Record 33 of Set 7 | kaeo
# Processing Record 34 of Set 7 | nizwa
# Processing Record 35 of Set 7 | eureka
# Processing Record 36 of Set 7 | kalga
# Processing Record 37 of Set 7 | nanortalik
# Processing Record 38 of Set 7 | sarkand
# Processing Record 39 of Set 7 | puerto maldonado
# Processing Record 40 of Set 7 | atar
# Processing Record 41 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 7 | umm kaddadah
# Processing Record 43 of Set 7 | black river
# Processing Record 44 of Set 7 | port hueneme
# Processing Record 45 of Set 7 | novo aripuana
# Processing Record 46 of Set 7 | bocaiuva
# Processing Record 47 of Set 7 | half moon bay
# Processing Record 48 of Set 7 | caravelas
# Processing Record 49 of Set 7 | kudahuvadhoo
# Processing Record 50 of Set 7 | mungwi
# Processing Record 1 of Set 8 | olafsvik
# Processing Record 2 of Set 8 | lucapa
# Processing Record 3 of Set 8 | senmonorom
# City not found. Skipping...
# Processing Record 4 of Set 8 | bibai
# Processing Record 5 of Set 8 | sinnamary
# Processing Record 6 of Set 8 | ponta do sol
# Processing Record 7 of Set 8 | paamiut
# Processing Record 8 of Set 8 | broken hill
# Processing Record 9 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 10 of Set 8 | fukue
# Processing Record 11 of Set 8 | san cristobal
# Processing Record 12 of Set 8 | boyolangu
# Processing Record 13 of Set 8 | achisay
# City not found. Skipping...
# Processing Record 14 of Set 8 | boddam
# Processing Record 15 of Set 8 | platteville
# Processing Record 16 of Set 8 | comodoro rivadavia
# Processing Record 17 of Set 8 | mednogorsk
# Processing Record 18 of Set 8 | sulangan
# Processing Record 19 of Set 8 | webuye
# Processing Record 20 of Set 8 | sechelt
# Processing Record 21 of Set 8 | wana
# Processing Record 22 of Set 8 | medea
# Processing Record 23 of Set 8 | san vicente
# Processing Record 24 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 25 of Set 8 | grand island
# Processing Record 26 of Set 8 | honiara
# Processing Record 27 of Set 8 | kiruna
# Processing Record 28 of Set 8 | sayanogorsk
# Processing Record 29 of Set 8 | misratah
# Processing Record 30 of Set 8 | balykshi
# Processing Record 31 of Set 8 | leh
# Processing Record 32 of Set 8 | pisco
# Processing Record 33 of Set 8 | dudinka
# Processing Record 34 of Set 8 | buala
# Processing Record 35 of Set 8 | liepaja
# Processing Record 36 of Set 8 | kautokeino
# Processing Record 37 of Set 8 | collie
# Processing Record 38 of Set 8 | compostela
# Processing Record 39 of Set 8 | ugoofaaru
# Processing Record 40 of Set 8 | hofn
# Processing Record 41 of Set 8 | qeshm
# Processing Record 42 of Set 8 | evensk
# Processing Record 43 of Set 8 | kutum
# Processing Record 44 of Set 8 | sale
# Processing Record 45 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | port hardy
# Processing Record 48 of Set 8 | cabo rojo
# Processing Record 49 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 8 | ambon
# Processing Record 1 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 9 | lorengau
# Processing Record 3 of Set 9 | chokwe
# Processing Record 4 of Set 9 | matata
# Processing Record 5 of Set 9 | dicabisagan
# Processing Record 6 of Set 9 | bereda
# Processing Record 7 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 9 | hvolsvollur
# Processing Record 9 of Set 9 | huarmey
# Processing Record 10 of Set 9 | bubaque
# Processing Record 11 of Set 9 | kushima
# Processing Record 12 of Set 9 | huilong
# Processing Record 13 of Set 9 | waddan
# Processing Record 14 of Set 9 | catole do rocha
# Processing Record 15 of Set 9 | centralina
# Processing Record 16 of Set 9 | talnakh
# Processing Record 17 of Set 9 | mangrol
# Processing Record 18 of Set 9 | lufilufi
# Processing Record 19 of Set 9 | poum
# Processing Record 20 of Set 9 | odweyne
# Processing Record 21 of Set 9 | canaries
# Processing Record 22 of Set 9 | vestmanna
# Processing Record 23 of Set 9 | sochi
# Processing Record 24 of Set 9 | bang saphan
# Processing Record 25 of Set 9 | lively
# Processing Record 26 of Set 9 | lompoc
# Processing Record 27 of Set 9 | dawei
# Processing Record 28 of Set 9 | tifton
# Processing Record 29 of Set 9 | zachagansk
# City not found. Skipping...
# Processing Record 30 of Set 9 | nchelenge
# Processing Record 31 of Set 9 | kysyl-syr
# Processing Record 32 of Set 9 | taltal
# Processing Record 33 of Set 9 | oriximina
# Processing Record 34 of Set 9 | mazatlan
# Processing Record 35 of Set 9 | san matias
# Processing Record 36 of Set 9 | am timan
# Processing Record 37 of Set 9 | bhadrachalam
# Processing Record 38 of Set 9 | palana
# Processing Record 39 of Set 9 | anadyr
# Processing Record 40 of Set 9 | avera
# Processing Record 41 of Set 9 | baksheyevo
# Processing Record 42 of Set 9 | slave lake
# Processing Record 43 of Set 9 | miri
# Processing Record 44 of Set 9 | sabang
# Processing Record 45 of Set 9 | zhoucheng
# Processing Record 46 of Set 9 | panorama
# Processing Record 47 of Set 9 | kruisfontein
# Processing Record 48 of Set 9 | preobrazheniye
# Processing Record 49 of Set 9 | semme
# Processing Record 50 of Set 9 | qandala
# Processing Record 1 of Set 10 | one hundred mile house
# City not found. Skipping...
# Processing Record 2 of Set 10 | kavaratti
# Processing Record 3 of Set 10 | young
# Processing Record 4 of Set 10 | husum
# Processing Record 5 of Set 10 | hasaki
# Processing Record 6 of Set 10 | helong
# Processing Record 7 of Set 10 | berlevag
# Processing Record 8 of Set 10 | westport
# Processing Record 9 of Set 10 | kayes
# Processing Record 10 of Set 10 | ulladulla
# Processing Record 11 of Set 10 | booue
# Processing Record 12 of Set 10 | manama
# Processing Record 13 of Set 10 | chekhov
# Processing Record 14 of Set 10 | pale
# Processing Record 15 of Set 10 | laguna
# Processing Record 16 of Set 10 | peniche
# Processing Record 17 of Set 10 | verkhoyansk
# Processing Record 18 of Set 10 | buhe
# Processing Record 19 of Set 10 | surin
# Processing Record 20 of Set 10 | cururupu
# Processing Record 21 of Set 10 | sulina
# Processing Record 22 of Set 10 | gustrow
# Processing Record 23 of Set 10 | nhulunbuy
# Processing Record 24 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 25 of Set 10 | owosso
# Processing Record 26 of Set 10 | rawalpindi
# Processing Record 27 of Set 10 | butembo
# Processing Record 28 of Set 10 | pacific grove
# Processing Record 29 of Set 10 | san juan
# Processing Record 30 of Set 10 | choya
# Processing Record 31 of Set 10 | rio branco
# Processing Record 32 of Set 10 | altay
# Processing Record 33 of Set 10 | camopi
# Processing Record 34 of Set 10 | tungor
# Processing Record 35 of Set 10 | severo-kurilsk
# Processing Record 36 of Set 10 | muroto
# Processing Record 37 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 10 | druzhba
# Processing Record 39 of Set 10 | constantine
# Processing Record 40 of Set 10 | krasnoshchekovo
# Processing Record 41 of Set 10 | sao filipe
# Processing Record 42 of Set 10 | fort nelson
# Processing Record 43 of Set 10 | anloga
# Processing Record 44 of Set 10 | ukiah
# Processing Record 45 of Set 10 | grand gaube
# Processing Record 46 of Set 10 | batsfjord
# Processing Record 47 of Set 10 | tura
# Processing Record 48 of Set 10 | hobyo
# Processing Record 49 of Set 10 | miranda
# Processing Record 50 of Set 10 | praia da vitoria
# Processing Record 1 of Set 11 | siwani
# City not found. Skipping...
# Processing Record 2 of Set 11 | santa cruz
# Processing Record 3 of Set 11 | nador
# Processing Record 4 of Set 11 | moron
# Processing Record 5 of Set 11 | sakaiminato
# Processing Record 6 of Set 11 | haverfordwest
# Processing Record 7 of Set 11 | chabahar
# Processing Record 8 of Set 11 | voyinka
# Processing Record 9 of Set 11 | torbat-e jam
# Processing Record 10 of Set 11 | darovskoy
# Processing Record 11 of Set 11 | auray
# Processing Record 12 of Set 11 | zhezkazgan
# Processing Record 13 of Set 11 | kroya
# Processing Record 14 of Set 11 | morehead
# Processing Record 15 of Set 11 | belmonte
# Processing Record 16 of Set 11 | kaitangata
# Processing Record 17 of Set 11 | puerto baquerizo moreno
# Processing Record 18 of Set 11 | arraias
# Processing Record 19 of Set 11 | lagoa
# Processing Record 20 of Set 11 | oranjestad
# Processing Record 21 of Set 11 | manta
# Processing Record 22 of Set 11 | awka
# Processing Record 23 of Set 11 | shimoda
# Processing Record 24 of Set 11 | faanui
# Processing Record 25 of Set 11 | tsumeb
# Processing Record 26 of Set 11 | hede
# Processing Record 27 of Set 11 | alamogordo
# Processing Record 28 of Set 11 | quatre cocos
# Processing Record 29 of Set 11 | mnogovershinnyy
# Processing Record 30 of Set 11 | ornes
# Processing Record 31 of Set 11 | mecca
# Processing Record 32 of Set 11 | macusani
# Processing Record 33 of Set 11 | port blair
# Processing Record 34 of Set 11 | tambura
# Processing Record 35 of Set 11 | tarko-sale
# Processing Record 36 of Set 11 | ouegoa
# Processing Record 37 of Set 11 | boca do acre
# Processing Record 38 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 39 of Set 11 | jaragua
# Processing Record 40 of Set 11 | jardim
# Processing Record 41 of Set 11 | kibala
# Processing Record 42 of Set 11 | rantauprapat
# Processing Record 43 of Set 11 | zhongxing
# Processing Record 44 of Set 11 | yumen
# Processing Record 45 of Set 11 | seoul
# Processing Record 46 of Set 11 | cayenne
# Processing Record 47 of Set 11 | miranorte
# City not found. Skipping...
# Processing Record 48 of Set 11 | semirom
# Processing Record 49 of Set 11 | sungairaya
# Processing Record 50 of Set 11 | anqing
# Processing Record 1 of Set 12 | wawina
# Processing Record 2 of Set 12 | lampazos de naranjo
# Processing Record 3 of Set 12 | vardo
# Processing Record 4 of Set 12 | jalu
# Processing Record 5 of Set 12 | barbar
# City not found. Skipping...
# Processing Record 6 of Set 12 | bulgan
# Processing Record 7 of Set 12 | bayonne
# Processing Record 8 of Set 12 | aljezur
# Processing Record 9 of Set 12 | chapais
# Processing Record 10 of Set 12 | bilibino
# Processing Record 11 of Set 12 | metro
# Processing Record 12 of Set 12 | haradok
# Processing Record 13 of Set 12 | rehoboth
# Processing Record 14 of Set 12 | santa cruz do rio pardo
# Processing Record 15 of Set 12 | santa vitoria do palmar
# Processing Record 16 of Set 12 | corowa
# Processing Record 17 of Set 12 | corinto
# Processing Record 18 of Set 12 | bay roberts
# Processing Record 19 of Set 12 | saryshagan
# City not found. Skipping...
# Processing Record 20 of Set 12 | colombo
# Processing Record 21 of Set 12 | kerrville
# Processing Record 22 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 12 | aripuana
# Processing Record 24 of Set 12 | jiwani
# Processing Record 25 of Set 12 | awbari
# Processing Record 26 of Set 12 | kyshtovka
# Processing Record 27 of Set 12 | florianopolis
# Processing Record 28 of Set 12 | candido mendes
# Processing Record 29 of Set 12 | haines junction
# Processing Record 30 of Set 12 | bowen
# Processing Record 31 of Set 12 | binga
# Processing Record 32 of Set 12 | vostok
# Processing Record 33 of Set 12 | beringovskiy
# Processing Record 34 of Set 12 | hay river
# Processing Record 35 of Set 12 | bagotville
# Processing Record 36 of Set 12 | betlitsa
# Processing Record 37 of Set 12 | yaan
# Processing Record 38 of Set 12 | lake city
# Processing Record 39 of Set 12 | ponta delgada
# Processing Record 40 of Set 12 | havre-saint-pierre
# Processing Record 41 of Set 12 | bairiki
# Processing Record 42 of Set 12 | port moresby
# Processing Record 43 of Set 12 | calvinia
# Processing Record 44 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 45 of Set 12 | lumsden
# Processing Record 46 of Set 12 | pacifica
# Processing Record 47 of Set 12 | mwinilunga
# Processing Record 48 of Set 12 | college
# Processing Record 49 of Set 12 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 12 | gigmoto
# Processing Record 1 of Set 13 | krasnoselkup
# Processing Record 2 of Set 13 | sao miguel do araguaia
# Processing Record 3 of Set 13 | jiangyou
# Processing Record 4 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 13 | ketchikan
# Processing Record 6 of Set 13 | ulagan
# Processing Record 7 of Set 13 | clyde river
# Processing Record 8 of Set 13 | camacha
# Processing Record 9 of Set 13 | bell ville
# Processing Record 10 of Set 13 | beloha
# Processing Record 11 of Set 13 | flinders
# Processing Record 12 of Set 13 | nerja
# Processing Record 13 of Set 13 | vigia
# Processing Record 14 of Set 13 | duluth
# Processing Record 15 of Set 13 | xudat
# Processing Record 16 of Set 13 | conceicao do araguaia
# Processing Record 17 of Set 13 | wanning
# Processing Record 18 of Set 13 | tripoli
# Processing Record 19 of Set 13 | launceston
# Processing Record 20 of Set 13 | kropachevo
# Processing Record 21 of Set 13 | zheleznodorozhnyy
# Processing Record 22 of Set 13 | alihe
# Processing Record 23 of Set 13 | konakovo
# Processing Record 24 of Set 13 | chake chake
# Processing Record 25 of Set 13 | goderich
# Processing Record 26 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 27 of Set 13 | yaita
# Processing Record 28 of Set 13 | binzhou
# Processing Record 29 of Set 13 | biak
# Processing Record 30 of Set 13 | bac giang
# Processing Record 31 of Set 13 | malinovoye ozero
# Processing Record 32 of Set 13 | jurm
# Processing Record 33 of Set 13 | nemuro
# Processing Record 34 of Set 13 | charlestown
# Processing Record 35 of Set 13 | mitu
# Processing Record 36 of Set 13 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 13 | kulhudhuffushi
# Processing Record 38 of Set 13 | gaozhou
# Processing Record 39 of Set 13 | bonthe
# Processing Record 40 of Set 13 | makakilo city
# Processing Record 41 of Set 13 | inirida
# Processing Record 42 of Set 13 | vaitape
# Processing Record 43 of Set 13 | mataram
# Processing Record 44 of Set 13 | yalvac
# Processing Record 45 of Set 13 | juifang
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 645

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Ribeira Grande  38.5167  -28.7000     63.77        85         100
# 1           Portland  45.5234 -122.6762     58.95        94         100
# 2        Tuktoyaktuk  69.4541 -133.0374     10.40        85         100
# 3          Centralia  46.7162 -122.9543     57.43        97         100
# 4                Vao -22.6667  167.4833     75.02        87          66
# 5  San Mateo Ixtatan  15.8319  -91.4781     51.49        97         100
# 6          Sept-Iles  50.2001  -66.3821     55.40        74          20
# 7            Kunming  25.0389  102.7183     53.53        82          40
# 8               Lata  40.1629   -8.3327     43.07        74           7
# 9          Mount Isa -20.7333  139.5000     87.57        27          40
#
#    Wind Speed Country                 Date
# 0        1.99      PT  2022-11-05 02:49:10
# 1       17.27      US  2022-11-05 02:48:31
# 2       12.66      CA  2022-11-05 02:49:10
# 3        9.22      US  2022-11-05 02:47:25
# 4       20.00      NC  2022-11-05 02:49:11
# 5        0.72      GT  2022-11-05 02:49:11
# 6       11.50      CA  2022-11-05 02:49:11
# 7        2.24      CN  2022-11-05 02:49:12
# 8        2.73      PT  2022-11-05 02:49:12
# 9        5.75      AU  2022-11-05 02:49:13

# %%
# Reorder the Columns of the DataFrame
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                 City Country                 Date      Lat       Lng  \
# 0     Ribeira Grande      PT  2022-11-05 02:49:10  38.5167  -28.7000
# 1           Portland      US  2022-11-05 02:48:31  45.5234 -122.6762
# 2        Tuktoyaktuk      CA  2022-11-05 02:49:10  69.4541 -133.0374
# 3          Centralia      US  2022-11-05 02:47:25  46.7162 -122.9543
# 4                Vao      NC  2022-11-05 02:49:11 -22.6667  167.4833
# 5  San Mateo Ixtatan      GT  2022-11-05 02:49:11  15.8319  -91.4781
# 6          Sept-Iles      CA  2022-11-05 02:49:11  50.2001  -66.3821
# 7            Kunming      CN  2022-11-05 02:49:12  25.0389  102.7183
# 8               Lata      PT  2022-11-05 02:49:12  40.1629   -8.3327
# 9          Mount Isa      AU  2022-11-05 02:49:13 -20.7333  139.5000
#
#    Max Temp  Humidity  Cloudiness  Wind Speed
# 0     63.77        85         100        1.99
# 1     58.95        94         100       17.27
# 2     10.40        85         100       12.66
# 3     57.43        97         100        9.22
# 4     75.02        87          66       20.00
# 5     51.49        97         100        0.72
# 6     55.40        74          20       11.50
# 7     53.53        82          40        2.24
# 8     43.07        74           7        2.73
# 9     87.57        27          40        5.75

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
            max_temps,
            edgecolor="black", linewidths=1, marker="o",
            alpha=0.8, label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()
