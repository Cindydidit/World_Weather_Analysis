# %%
# Deliverable 1. Retrieve Weather Data.

# RECREATED STARTER CODE FROM AS UNABLE TO UPLOAD (https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-online/module_6/Weather_Database_starter_code.ipynb).

# %%
# Import dependencies.
from citipy import citipy
import numpy as np
import pandas as pd
# Import libraries.
import requests
import time
# Import datetime module from datetime library.
from datetime import datetime
# Import API key.
from config import weather_api_key

# %%
# Use the np.random.uniform function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to get the nearest city for each latitude and longitude combination.

# %%
# Create a list to store city names.
cities = []
# Iterate through the coordinates()
for coordinate in coordinates:
    # Retrieve the nearest city using the latitude and longitude pair.
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is not in cities[]...
    if city not in cities:
        # Add it to the cities list.
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 766

# %%
# Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the config.py file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.

# %%
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Retrieve the following information from the API call:
# Latitude and longitude

# Maximum temperature

# Percent humidity

# Percent cloudiness

# Wind speed

# Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters to start at 1.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    # If the remainder of the index divided by 50 is equal to 0 and greater than 50.
    if (i % 50 == 0 and i >= 50):
        # Increment set_count by 1.
        set_count += 1
        # Increment record_count by 1.
        record_count = 1
        # 60 second pause to prevent time-out errors.
        time.sleep(60)

    # Create endpoint URL with each city.
    # Remove the blank spaces in the city name and concatenate the city name.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1 
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        #Assign variables for each piece of data we need.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
       
        city_weather_description=city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list in a dictionary format.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 1 | busselton
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | paamiut
# Processing Record 6 of Set 1 | shenjiamen
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | san patricio
# Processing Record 9 of Set 1 | constitucion
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | thompson
# Processing Record 12 of Set 1 | tautira
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bredasdorp
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | carnarvon
# Processing Record 18 of Set 1 | yunjinghong
# City not found. Skipping...
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | sovetskiy
# Processing Record 21 of Set 1 | grand centre
# City not found. Skipping...
# Processing Record 22 of Set 1 | santa rosa
# Processing Record 23 of Set 1 | pouebo
# Processing Record 24 of Set 1 | corinto
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | boueni
# Processing Record 27 of Set 1 | torbay
# Processing Record 28 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | bengkulu
# Processing Record 31 of Set 1 | rokytne
# Processing Record 32 of Set 1 | kjopsvik
# Processing Record 33 of Set 1 | puerto ayora
# Processing Record 34 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 35 of Set 1 | alexandria
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | vila velha
# Processing Record 38 of Set 1 | ossora
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | palkino
# Processing Record 42 of Set 1 | yulara
# Processing Record 43 of Set 1 | sanghar
# Processing Record 44 of Set 1 | esperance
# Processing Record 45 of Set 1 | barrow
# Processing Record 46 of Set 1 | souillac
# Processing Record 47 of Set 1 | laela
# Processing Record 48 of Set 1 | bandraboua
# Processing Record 49 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 50 of Set 1 | axim
# Processing Record 1 of Set 2 | albany
# Processing Record 2 of Set 2 | hithadhoo
# Processing Record 3 of Set 2 | kavieng
# Processing Record 4 of Set 2 | agadir
# Processing Record 5 of Set 2 | alappuzha
# Processing Record 6 of Set 2 | san cristobal
# Processing Record 7 of Set 2 | salta
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 10 of Set 2 | saint george
# Processing Record 11 of Set 2 | pathein
# Processing Record 12 of Set 2 | mataura
# Processing Record 13 of Set 2 | mahaicony
# City not found. Skipping...
# Processing Record 14 of Set 2 | terney
# Processing Record 15 of Set 2 | provideniya
# Processing Record 16 of Set 2 | san rafael
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | bilibino
# Processing Record 19 of Set 2 | dakar
# Processing Record 20 of Set 2 | cockburn town
# Processing Record 21 of Set 2 | asau
# Processing Record 22 of Set 2 | preston
# Processing Record 23 of Set 2 | severo-kurilsk
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | kysyl-syr
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | broome
# Processing Record 28 of Set 2 | hobart
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | pereleshino
# Processing Record 31 of Set 2 | tuatapere
# Processing Record 32 of Set 2 | saldanha
# Processing Record 33 of Set 2 | middelburg
# Processing Record 34 of Set 2 | walvis bay
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | itoman
# Processing Record 37 of Set 2 | harper
# Processing Record 38 of Set 2 | port alfred
# Processing Record 39 of Set 2 | cherskiy
# Processing Record 40 of Set 2 | the valley
# Processing Record 41 of Set 2 | bambous virieux
# Processing Record 42 of Set 2 | arlit
# Processing Record 43 of Set 2 | mount gambier
# Processing Record 44 of Set 2 | muros
# Processing Record 45 of Set 2 | namibe
# Processing Record 46 of Set 2 | mayo
# Processing Record 47 of Set 2 | ritchie
# Processing Record 48 of Set 2 | mont-de-marsan
# Processing Record 49 of Set 2 | avarua
# Processing Record 50 of Set 2 | bethel
# Processing Record 1 of Set 3 | port macquarie
# Processing Record 2 of Set 3 | amambai
# Processing Record 3 of Set 3 | minas
# Processing Record 4 of Set 3 | vila franca do campo
# Processing Record 5 of Set 3 | chifeng
# Processing Record 6 of Set 3 | puerto maldonado
# Processing Record 7 of Set 3 | hermanus
# Processing Record 8 of Set 3 | oistins
# Processing Record 9 of Set 3 | hovd
# Processing Record 10 of Set 3 | marsh harbour
# Processing Record 11 of Set 3 | husavik
# Processing Record 12 of Set 3 | linxia
# Processing Record 13 of Set 3 | santa luzia
# Processing Record 14 of Set 3 | vila do maio
# Processing Record 15 of Set 3 | tocopilla
# Processing Record 16 of Set 3 | guerrero negro
# Processing Record 17 of Set 3 | wagar
# Processing Record 18 of Set 3 | qaanaaq
# Processing Record 19 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 3 | novobirilyussy
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | ganzhou
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 25 of Set 3 | kupino
# Processing Record 26 of Set 3 | new norfolk
# Processing Record 27 of Set 3 | urfa
# City not found. Skipping...
# Processing Record 28 of Set 3 | leninsk
# Processing Record 29 of Set 3 | yanan
# City not found. Skipping...
# Processing Record 30 of Set 3 | alice springs
# Processing Record 31 of Set 3 | suhbaatar
# Processing Record 32 of Set 3 | belawan
# Processing Record 33 of Set 3 | ximei
# Processing Record 34 of Set 3 | lebu
# Processing Record 35 of Set 3 | srednekolymsk
# Processing Record 36 of Set 3 | ust-nera
# Processing Record 37 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 38 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 3 | tabas
# Processing Record 40 of Set 3 | rathdrum
# Processing Record 41 of Set 3 | tiksi
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | nishihara
# Processing Record 44 of Set 3 | mastic beach
# Processing Record 45 of Set 3 | manokwari
# Processing Record 46 of Set 3 | gat
# Processing Record 47 of Set 3 | margate
# Processing Record 48 of Set 3 | zholymbet
# Processing Record 49 of Set 3 | dieppe bay
# City not found. Skipping...
# Processing Record 50 of Set 3 | kargopol
# Processing Record 1 of Set 4 | korablino
# Processing Record 2 of Set 4 | longyearbyen
# Processing Record 3 of Set 4 | poum
# Processing Record 4 of Set 4 | jamestown
# Processing Record 5 of Set 4 | pyay
# Processing Record 6 of Set 4 | hasaki
# Processing Record 7 of Set 4 | saint-donat-de-montcalm
# Processing Record 8 of Set 4 | mar del plata
# Processing Record 9 of Set 4 | zhuji
# Processing Record 10 of Set 4 | marzuq
# Processing Record 11 of Set 4 | buala
# Processing Record 12 of Set 4 | susanino
# Processing Record 13 of Set 4 | staraya mayna
# Processing Record 14 of Set 4 | katsuura
# Processing Record 15 of Set 4 | castro
# Processing Record 16 of Set 4 | san juan
# Processing Record 17 of Set 4 | komsomolskiy
# Processing Record 18 of Set 4 | kirakira
# Processing Record 19 of Set 4 | jardim
# Processing Record 20 of Set 4 | morwell
# Processing Record 21 of Set 4 | dickinson
# Processing Record 22 of Set 4 | challapata
# Processing Record 23 of Set 4 | bur gabo
# City not found. Skipping...
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 26 of Set 4 | yinchuan
# Processing Record 27 of Set 4 | kieta
# Processing Record 28 of Set 4 | kailua
# Processing Record 29 of Set 4 | soe
# Processing Record 30 of Set 4 | taltal
# Processing Record 31 of Set 4 | huatulco
# Processing Record 32 of Set 4 | salinopolis
# Processing Record 33 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 34 of Set 4 | east london
# Processing Record 35 of Set 4 | hobyo
# Processing Record 36 of Set 4 | juneau
# Processing Record 37 of Set 4 | bahia blanca
# Processing Record 38 of Set 4 | lewistown
# Processing Record 39 of Set 4 | luena
# Processing Record 40 of Set 4 | sindor
# Processing Record 41 of Set 4 | lagoa
# Processing Record 42 of Set 4 | tambacounda
# Processing Record 43 of Set 4 | rottenburg
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | galle
# Processing Record 46 of Set 4 | lompoc
# Processing Record 47 of Set 4 | vao
# Processing Record 48 of Set 4 | pisco
# Processing Record 49 of Set 4 | airai
# Processing Record 50 of Set 4 | silivri
# Processing Record 1 of Set 5 | arraial do cabo
# Processing Record 2 of Set 5 | caravelas
# Processing Record 3 of Set 5 | mecca
# Processing Record 4 of Set 5 | grand gaube
# Processing Record 5 of Set 5 | sola
# Processing Record 6 of Set 5 | robertsport
# Processing Record 7 of Set 5 | bam
# Processing Record 8 of Set 5 | meadow lake
# Processing Record 9 of Set 5 | bukama
# Processing Record 10 of Set 5 | inhambane
# Processing Record 11 of Set 5 | hitoyoshi
# Processing Record 12 of Set 5 | codrington
# Processing Record 13 of Set 5 | zhigansk
# Processing Record 14 of Set 5 | sao filipe
# Processing Record 15 of Set 5 | birao
# Processing Record 16 of Set 5 | poanas
# Processing Record 17 of Set 5 | tuktoyaktuk
# Processing Record 18 of Set 5 | portland
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | lesnoy
# Processing Record 22 of Set 5 | dawlatabad
# Processing Record 23 of Set 5 | okitipupa
# Processing Record 24 of Set 5 | buchanan
# Processing Record 25 of Set 5 | port hardy
# Processing Record 26 of Set 5 | necochea
# Processing Record 27 of Set 5 | wa
# City not found. Skipping...
# Processing Record 28 of Set 5 | geraldton
# Processing Record 29 of Set 5 | sakakah
# Processing Record 30 of Set 5 | yellowknife
# Processing Record 31 of Set 5 | hambantota
# Processing Record 32 of Set 5 | talnakh
# Processing Record 33 of Set 5 | sitrah
# Processing Record 34 of Set 5 | victoria
# Processing Record 35 of Set 5 | ketchikan
# Processing Record 36 of Set 5 | stornoway
# Processing Record 37 of Set 5 | nichinan
# Processing Record 38 of Set 5 | muzaffarabad
# Processing Record 39 of Set 5 | jilib
# Processing Record 40 of Set 5 | port blair
# Processing Record 41 of Set 5 | coquimbo
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | luderitz
# Processing Record 44 of Set 5 | esso
# Processing Record 45 of Set 5 | adrar
# Processing Record 46 of Set 5 | ewa beach
# Processing Record 47 of Set 5 | butembo
# Processing Record 48 of Set 5 | henties bay
# Processing Record 49 of Set 5 | praia
# Processing Record 50 of Set 5 | la ronge
# Processing Record 1 of Set 6 | taoudenni
# Processing Record 2 of Set 6 | wewak
# Processing Record 3 of Set 6 | meulaboh
# Processing Record 4 of Set 6 | masuguru
# Processing Record 5 of Set 6 | richards bay
# Processing Record 6 of Set 6 | stawell
# Processing Record 7 of Set 6 | athabasca
# Processing Record 8 of Set 6 | celestun
# Processing Record 9 of Set 6 | klaksvik
# Processing Record 10 of Set 6 | la palma
# Processing Record 11 of Set 6 | butaritari
# Processing Record 12 of Set 6 | tecoanapa
# Processing Record 13 of Set 6 | chokurdakh
# Processing Record 14 of Set 6 | surab
# Processing Record 15 of Set 6 | alpena
# Processing Record 16 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | takoradi
# Processing Record 19 of Set 6 | inta
# Processing Record 20 of Set 6 | karpathos
# Processing Record 21 of Set 6 | madimba
# Processing Record 22 of Set 6 | asfi
# Processing Record 23 of Set 6 | comodoro rivadavia
# Processing Record 24 of Set 6 | gazojak
# Processing Record 25 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 6 | mitu
# Processing Record 27 of Set 6 | pangody
# Processing Record 28 of Set 6 | olafsvik
# Processing Record 29 of Set 6 | port augusta
# Processing Record 30 of Set 6 | general roca
# Processing Record 31 of Set 6 | narsaq
# Processing Record 32 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 33 of Set 6 | rockport
# Processing Record 34 of Set 6 | nome
# Processing Record 35 of Set 6 | saint-philippe
# Processing Record 36 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 37 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 6 | plettenberg bay
# Processing Record 39 of Set 6 | dingle
# Processing Record 40 of Set 6 | chuy
# Processing Record 41 of Set 6 | rosario
# Processing Record 42 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 6 | atchison
# Processing Record 44 of Set 6 | faya
# Processing Record 45 of Set 6 | krasnoselkup
# Processing Record 46 of Set 6 | sorland
# Processing Record 47 of Set 6 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 6 | high level
# Processing Record 49 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 6 | dudinka
# Processing Record 1 of Set 7 | isla vista
# Processing Record 2 of Set 7 | karaton
# Processing Record 3 of Set 7 | batsfjord
# Processing Record 4 of Set 7 | erenhot
# Processing Record 5 of Set 7 | ilulissat
# Processing Record 6 of Set 7 | kango
# Processing Record 7 of Set 7 | ajdabiya
# Processing Record 8 of Set 7 | phan thiet
# Processing Record 9 of Set 7 | karwar
# Processing Record 10 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 11 of Set 7 | lucea
# Processing Record 12 of Set 7 | kutum
# Processing Record 13 of Set 7 | inirida
# Processing Record 14 of Set 7 | port lincoln
# Processing Record 15 of Set 7 | puerto leguizamo
# Processing Record 16 of Set 7 | palmas bellas
# Processing Record 17 of Set 7 | mangochi
# Processing Record 18 of Set 7 | alofi
# Processing Record 19 of Set 7 | westport
# Processing Record 20 of Set 7 | honningsvag
# Processing Record 21 of Set 7 | carutapera
# Processing Record 22 of Set 7 | rognan
# Processing Record 23 of Set 7 | chimore
# Processing Record 24 of Set 7 | bayan
# Processing Record 25 of Set 7 | leh
# Processing Record 26 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 27 of Set 7 | ilmajoki
# Processing Record 28 of Set 7 | natal
# Processing Record 29 of Set 7 | gardez
# Processing Record 30 of Set 7 | touros
# Processing Record 31 of Set 7 | acapulco
# Processing Record 32 of Set 7 | ekhabi
# Processing Record 33 of Set 7 | pingliang
# Processing Record 34 of Set 7 | pio ix
# Processing Record 35 of Set 7 | kadykchan
# City not found. Skipping...
# Processing Record 36 of Set 7 | kokstad
# Processing Record 37 of Set 7 | makakilo city
# Processing Record 38 of Set 7 | matehuala
# Processing Record 39 of Set 7 | san policarpo
# Processing Record 40 of Set 7 | havoysund
# Processing Record 41 of Set 7 | leningradskiy
# Processing Record 42 of Set 7 | key west
# Processing Record 43 of Set 7 | sangmelima
# Processing Record 44 of Set 7 | le port
# Processing Record 45 of Set 7 | nemuro
# Processing Record 46 of Set 7 | panixtlahuaca
# City not found. Skipping...
# Processing Record 47 of Set 7 | jumla
# Processing Record 48 of Set 7 | mahebourg
# Processing Record 49 of Set 7 | mutoko
# Processing Record 50 of Set 7 | khatassy
# Processing Record 1 of Set 8 | coihaique
# Processing Record 2 of Set 8 | port hawkesbury
# Processing Record 3 of Set 8 | zyryanka
# Processing Record 4 of Set 8 | kirkenaer
# Processing Record 5 of Set 8 | huazolotitlan
# City not found. Skipping...
# Processing Record 6 of Set 8 | kununurra
# Processing Record 7 of Set 8 | peleduy
# Processing Record 8 of Set 8 | amapa
# Processing Record 9 of Set 8 | zhezkazgan
# Processing Record 10 of Set 8 | palu
# Processing Record 11 of Set 8 | saurimo
# Processing Record 12 of Set 8 | nsanje
# Processing Record 13 of Set 8 | kupang
# Processing Record 14 of Set 8 | veinticinco de mayo
# Processing Record 15 of Set 8 | santa cruz
# Processing Record 16 of Set 8 | kalmunai
# Processing Record 17 of Set 8 | sena madureira
# Processing Record 18 of Set 8 | north bend
# Processing Record 19 of Set 8 | lodwar
# Processing Record 20 of Set 8 | macusani
# Processing Record 21 of Set 8 | ambon
# Processing Record 22 of Set 8 | pangkalanbuun
# Processing Record 23 of Set 8 | rehoboth
# Processing Record 24 of Set 8 | erzin
# Processing Record 25 of Set 8 | madison heights
# Processing Record 26 of Set 8 | saskylakh
# Processing Record 27 of Set 8 | nampula
# Processing Record 28 of Set 8 | troitskoye
# Processing Record 29 of Set 8 | conde
# Processing Record 30 of Set 8 | severomorsk
# Processing Record 31 of Set 8 | kerrobert
# Processing Record 32 of Set 8 | bintulu
# Processing Record 33 of Set 8 | cayenne
# Processing Record 34 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 35 of Set 8 | sisimiut
# Processing Record 36 of Set 8 | atar
# Processing Record 37 of Set 8 | nusaybin
# Processing Record 38 of Set 8 | mbini
# Processing Record 39 of Set 8 | huanren
# Processing Record 40 of Set 8 | liku
# Processing Record 41 of Set 8 | nanortalik
# Processing Record 42 of Set 8 | yaan
# Processing Record 43 of Set 8 | camacha
# Processing Record 44 of Set 8 | longyan
# Processing Record 45 of Set 8 | xingcheng
# Processing Record 46 of Set 8 | kumluca
# Processing Record 47 of Set 8 | burica
# City not found. Skipping...
# Processing Record 48 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 8 | pevek
# Processing Record 50 of Set 8 | lorengau
# Processing Record 1 of Set 9 | mabaruma
# Processing Record 2 of Set 9 | ponta do sol
# Processing Record 3 of Set 9 | estevan
# Processing Record 4 of Set 9 | estrela
# Processing Record 5 of Set 9 | yumen
# Processing Record 6 of Set 9 | camacari
# Processing Record 7 of Set 9 | barranca
# Processing Record 8 of Set 9 | roald
# Processing Record 9 of Set 9 | podor
# Processing Record 10 of Set 9 | naze
# Processing Record 11 of Set 9 | nioro
# Processing Record 12 of Set 9 | swan river
# Processing Record 13 of Set 9 | tabory
# Processing Record 14 of Set 9 | kirovo-chepetsk
# Processing Record 15 of Set 9 | batagay
# Processing Record 16 of Set 9 | bakchar
# Processing Record 17 of Set 9 | brae
# Processing Record 18 of Set 9 | xining
# Processing Record 19 of Set 9 | blagoyevo
# Processing Record 20 of Set 9 | xuddur
# Processing Record 21 of Set 9 | ozernovskiy
# Processing Record 22 of Set 9 | hammerfest
# Processing Record 23 of Set 9 | texarkana
# Processing Record 24 of Set 9 | nauta
# Processing Record 25 of Set 9 | gombong
# Processing Record 26 of Set 9 | dindori
# Processing Record 27 of Set 9 | vostok
# Processing Record 28 of Set 9 | iralaya
# Processing Record 29 of Set 9 | san quintin
# Processing Record 30 of Set 9 | suba
# Processing Record 31 of Set 9 | mbandaka
# Processing Record 32 of Set 9 | nacala
# Processing Record 33 of Set 9 | tsagan aman
# Processing Record 34 of Set 9 | platanos
# Processing Record 35 of Set 9 | banda aceh
# Processing Record 36 of Set 9 | altay
# Processing Record 37 of Set 9 | quatre cocos
# Processing Record 38 of Set 9 | callaway
# Processing Record 39 of Set 9 | newtonmore
# Processing Record 40 of Set 9 | pemba
# Processing Record 41 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 42 of Set 9 | swan hill
# Processing Record 43 of Set 9 | miraflores
# Processing Record 44 of Set 9 | bonavista
# Processing Record 45 of Set 9 | strelka
# Processing Record 46 of Set 9 | chudniv
# Processing Record 47 of Set 9 | saint anthony
# Processing Record 48 of Set 9 | obo
# Processing Record 49 of Set 9 | palmer
# Processing Record 50 of Set 9 | khandyga
# Processing Record 1 of Set 10 | winsum
# Processing Record 2 of Set 10 | vaasa
# Processing Record 3 of Set 10 | mandera
# Processing Record 4 of Set 10 | tongliao
# Processing Record 5 of Set 10 | nam tha
# City not found. Skipping...
# Processing Record 6 of Set 10 | thilogne
# City not found. Skipping...
# Processing Record 7 of Set 10 | brigantine
# Processing Record 8 of Set 10 | asmar
# Processing Record 9 of Set 10 | arona
# Processing Record 10 of Set 10 | sroda wielkopolska
# Processing Record 11 of Set 10 | alta floresta
# Processing Record 12 of Set 10 | monrovia
# Processing Record 13 of Set 10 | santa isabel do rio negro
# Processing Record 14 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 15 of Set 10 | fukue
# Processing Record 16 of Set 10 | rosetta
# Processing Record 17 of Set 10 | kabinda
# Processing Record 18 of Set 10 | santa maria
# Processing Record 19 of Set 10 | punta alta
# Processing Record 20 of Set 10 | samarai
# Processing Record 21 of Set 10 | mehamn
# Processing Record 22 of Set 10 | korem
# Processing Record 23 of Set 10 | haines junction
# Processing Record 24 of Set 10 | guadalupe y calvo
# Processing Record 25 of Set 10 | malakal
# Processing Record 26 of Set 10 | shirokiy
# Processing Record 27 of Set 10 | houma
# Processing Record 28 of Set 10 | orgun
# City not found. Skipping...
# Processing Record 29 of Set 10 | zaoyang
# Processing Record 30 of Set 10 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 31 of Set 10 | hun
# Processing Record 32 of Set 10 | beringovskiy
# Processing Record 33 of Set 10 | kazachinskoye
# Processing Record 34 of Set 10 | tukrah
# Processing Record 35 of Set 10 | lavrentiya
# Processing Record 36 of Set 10 | pombia
# Processing Record 37 of Set 10 | catamarca
# Processing Record 38 of Set 10 | kopashnovo
# Processing Record 39 of Set 10 | ambilobe
# Processing Record 40 of Set 10 | fortuna
# Processing Record 41 of Set 10 | usakos
# Processing Record 42 of Set 10 | owando
# Processing Record 43 of Set 10 | clyde river
# Processing Record 44 of Set 10 | mitchell
# Processing Record 45 of Set 10 | mildura
# Processing Record 46 of Set 10 | faanui
# Processing Record 47 of Set 10 | burnie
# Processing Record 48 of Set 10 | port hedland
# Processing Record 49 of Set 10 | oparino
# Processing Record 50 of Set 10 | cromarty
# Processing Record 1 of Set 11 | jieshi
# Processing Record 2 of Set 11 | tazovskiy
# Processing Record 3 of Set 11 | seymchan
# Processing Record 4 of Set 11 | sarkand
# Processing Record 5 of Set 11 | yangambi
# Processing Record 6 of Set 11 | ola
# Processing Record 7 of Set 11 | arsk
# Processing Record 8 of Set 11 | novonikolayevskiy
# Processing Record 9 of Set 11 | ostrovnoy
# Processing Record 10 of Set 11 | hami
# Processing Record 11 of Set 11 | baruun-urt
# Processing Record 12 of Set 11 | quesnel
# Processing Record 13 of Set 11 | huambo
# Processing Record 14 of Set 11 | japura
# Processing Record 15 of Set 11 | siderno
# Processing Record 16 of Set 11 | luanda
# Processing Record 17 of Set 11 | solnechnyy
# Processing Record 18 of Set 11 | flinders
# Processing Record 19 of Set 11 | boralday
# Processing Record 20 of Set 11 | cravo norte
# Processing Record 21 of Set 11 | norman wells
# Processing Record 22 of Set 11 | bonthe
# Processing Record 23 of Set 11 | dragor
# Processing Record 24 of Set 11 | buraydah
# Processing Record 25 of Set 11 | arica
# Processing Record 26 of Set 11 | neiafu
# Processing Record 27 of Set 11 | dunedin
# Processing Record 28 of Set 11 | kahului
# Processing Record 29 of Set 11 | moose factory
# Processing Record 30 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 31 of Set 11 | vardo
# Processing Record 32 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 11 | alamosa
# Processing Record 34 of Set 11 | balkanabat
# Processing Record 35 of Set 11 | kapoeta
# Processing Record 36 of Set 11 | blois
# Processing Record 37 of Set 11 | batemans bay
# Processing Record 38 of Set 11 | zapolyarnyy
# Processing Record 39 of Set 11 | saint-leu
# Processing Record 40 of Set 11 | khlung
# Processing Record 41 of Set 11 | general pico
# Processing Record 42 of Set 11 | paita
# Processing Record 43 of Set 11 | dwarka
# Processing Record 44 of Set 11 | saint-denis
# Processing Record 45 of Set 11 | dubuque
# Processing Record 46 of Set 11 | hays
# Processing Record 47 of Set 11 | sete
# Processing Record 48 of Set 11 | beloha
# Processing Record 49 of Set 11 | kachikau
# City not found. Skipping...
# Processing Record 50 of Set 11 | olavarria
# Processing Record 1 of Set 12 | kavaratti
# Processing Record 2 of Set 12 | lalsot
# Processing Record 3 of Set 12 | dunmore town
# Processing Record 4 of Set 12 | lillesand
# Processing Record 5 of Set 12 | hualmay
# Processing Record 6 of Set 12 | nelson bay
# Processing Record 7 of Set 12 | khatanga
# Processing Record 8 of Set 12 | tanout
# Processing Record 9 of Set 12 | nouakchott
# Processing Record 10 of Set 12 | lufilufi
# Processing Record 11 of Set 12 | mareeba
# Processing Record 12 of Set 12 | agadez
# Processing Record 13 of Set 12 | great falls
# Processing Record 14 of Set 12 | chabahar
# Processing Record 15 of Set 12 | ponta delgada
# Processing Record 16 of Set 12 | hofn
# Processing Record 17 of Set 12 | miri
# Processing Record 18 of Set 12 | bage
# Processing Record 19 of Set 12 | marsa matruh
# Processing Record 20 of Set 12 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 21 of Set 12 | san vicente de canete
# Processing Record 22 of Set 12 | krasnyy kut
# Processing Record 23 of Set 12 | mbuguni
# Processing Record 24 of Set 12 | cairns
# Processing Record 25 of Set 12 | hamilton
# Processing Record 26 of Set 12 | punuare
# Processing Record 27 of Set 12 | timra
# Processing Record 28 of Set 12 | santa isabel
# Processing Record 29 of Set 12 | mutsamudu
# City not found. Skipping...
# Processing Record 30 of Set 12 | smithers
# Processing Record 31 of Set 12 | giresun
# Processing Record 32 of Set 12 | peniche
# Processing Record 33 of Set 12 | loviisa
# Processing Record 34 of Set 12 | portales
# Processing Record 35 of Set 12 | molochnoye
# Processing Record 36 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 37 of Set 12 | jinchengjiang
# City not found. Skipping...
# Processing Record 38 of Set 12 | hervey bay
# Processing Record 39 of Set 12 | auchi
# Processing Record 40 of Set 12 | kitakata
# Processing Record 41 of Set 12 | rafsanjan
# Processing Record 42 of Set 12 | ikalamavony
# Processing Record 43 of Set 12 | popondetta
# Processing Record 44 of Set 12 | yar-sale
# Processing Record 45 of Set 12 | salalah
# Processing Record 46 of Set 12 | boissevain
# Processing Record 47 of Set 12 | abu dhabi
# Processing Record 48 of Set 12 | talara
# Processing Record 49 of Set 12 | ellensburg
# Processing Record 50 of Set 12 | kota belud
# Processing Record 1 of Set 13 | iskateley
# Processing Record 2 of Set 13 | sao joao do paraiso
# Processing Record 3 of Set 13 | kochevo
# Processing Record 4 of Set 13 | matara
# Processing Record 5 of Set 13 | ruteng
# Processing Record 6 of Set 13 | kurilsk
# Processing Record 7 of Set 13 | acajutla
# Processing Record 8 of Set 13 | saint-pierre
# Processing Record 9 of Set 13 | darovskoy
# Processing Record 10 of Set 13 | half moon bay
# Processing Record 11 of Set 13 | olesnica
# Processing Record 12 of Set 13 | road town
# Processing Record 13 of Set 13 | adeje
# Processing Record 14 of Set 13 | amuntai
# Processing Record 15 of Set 13 | champerico
# Processing Record 16 of Set 13 | acarau
# Processing Record 17 of Set 13 | sioux lookout
# Processing Record 18 of Set 13 | rafai
# Processing Record 19 of Set 13 | lata
# Processing Record 20 of Set 13 | male
# Processing Record 21 of Set 13 | la trinitaria
# Processing Record 22 of Set 13 | san javier
# Processing Record 23 of Set 13 | nokaneng
# Processing Record 24 of Set 13 | aban
# Processing Record 25 of Set 13 | olga
# Processing Record 26 of Set 13 | qaqortoq
# Processing Record 27 of Set 13 | gomel
# Processing Record 28 of Set 13 | belaya gora
# Processing Record 29 of Set 13 | mingshui
# Processing Record 30 of Set 13 | berlevag
# Processing Record 31 of Set 13 | jamnah
# City not found. Skipping...
# Processing Record 32 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 13 | marang
# Processing Record 34 of Set 13 | martin
# Processing Record 35 of Set 13 | panique
# Processing Record 36 of Set 13 | karratha
# Processing Record 37 of Set 13 | puerto carreno
# Processing Record 38 of Set 13 | mana
# Processing Record 39 of Set 13 | tucumcari
# Processing Record 40 of Set 13 | usinsk
# Processing Record 41 of Set 13 | yacuiba
# Processing Record 42 of Set 13 | snezhnogorsk
# Processing Record 43 of Set 13 | moshny
# Processing Record 44 of Set 13 | sabang
# Processing Record 45 of Set 13 | toamasina
# Processing Record 46 of Set 13 | ouadda
# Processing Record 47 of Set 13 | mantamados
# Processing Record 48 of Set 13 | salinas
# Processing Record 49 of Set 13 | ternate
# Processing Record 50 of Set 13 | wad madani
# Processing Record 1 of Set 14 | avera
# Processing Record 2 of Set 14 | gravdal
# Processing Record 3 of Set 14 | sitka
# Processing Record 4 of Set 14 | irbil
# Processing Record 5 of Set 14 | sao joao da barra
# Processing Record 6 of Set 14 | moranbah
# Processing Record 7 of Set 14 | kibaya
# Processing Record 8 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 9 of Set 14 | huntsville
# Processing Record 10 of Set 14 | sibenik
# Processing Record 11 of Set 14 | tahe
# Processing Record 12 of Set 14 | brownwood
# Processing Record 13 of Set 14 | grindavik
# Processing Record 14 of Set 14 | isangel
# Processing Record 15 of Set 14 | yerraguntla
# Processing Record 16 of Set 14 | okha
# Processing Record 17 of Set 14 | petropavlovka
# Processing Record 18 of Set 14 | beira
# Processing Record 19 of Set 14 | yuzhnouralsk
# Processing Record 20 of Set 14 | port keats
# Processing Record 21 of Set 14 | aktanysh
# Processing Record 22 of Set 14 | loukhi
# Processing Record 23 of Set 14 | townsville
# Processing Record 24 of Set 14 | weiser
# Processing Record 25 of Set 14 | samarinda
# Processing Record 26 of Set 14 | ye
# City not found. Skipping...
# Processing Record 27 of Set 14 | christchurch
# Processing Record 28 of Set 14 | omboue
# Processing Record 29 of Set 14 | manika
# Processing Record 30 of Set 14 | elat
# Processing Record 31 of Set 14 | iskitim
# Processing Record 32 of Set 14 | los llanos de aridane
# Processing Record 33 of Set 14 | petropavl
# Processing Record 34 of Set 14 | nabire
# Processing Record 35 of Set 14 | shelby
# Processing Record 36 of Set 14 | lewiston
# Processing Record 37 of Set 14 | patur
# Processing Record 38 of Set 14 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 14 | sulina
# Processing Record 40 of Set 14 | havelock
# Processing Record 41 of Set 14 | chumikan
# Processing Record 42 of Set 14 | swellendam
# Processing Record 43 of Set 14 | pangnirtung
# Processing Record 44 of Set 14 | xichang
# Processing Record 45 of Set 14 | maraba
# Processing Record 46 of Set 14 | urdzhar
# City not found. Skipping...
# Processing Record 47 of Set 14 | onguday
# Processing Record 48 of Set 14 | poronaysk
# Processing Record 49 of Set 14 | siocon
# Processing Record 50 of Set 14 | gushikawa
# Processing Record 1 of Set 15 | roma
# Processing Record 2 of Set 15 | mazagao
# Processing Record 3 of Set 15 | vreed en hoop
# City not found. Skipping...
# Processing Record 4 of Set 15 | jujuy
# City not found. Skipping...
# Processing Record 5 of Set 15 | jijiga
# Processing Record 6 of Set 15 | teguldet
# Processing Record 7 of Set 15 | soure
# Processing Record 8 of Set 15 | santiago del estero
# Processing Record 9 of Set 15 | totness
# Processing Record 10 of Set 15 | mirik
# Processing Record 11 of Set 15 | boyabat
# Processing Record 12 of Set 15 | nikolsk
# Processing Record 13 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 14 of Set 15 | sonoita
# Processing Record 15 of Set 15 | te anau
# Processing Record 16 of Set 15 | quzhou
# Processing Record 17 of Set 15 | tombouctou
# Processing Record 18 of Set 15 | ceuta
# Processing Record 19 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 20 of Set 15 | broken hill
# Processing Record 21 of Set 15 | svidnik
# Processing Record 22 of Set 15 | tateyama
# Processing Record 23 of Set 15 | abong mbang
# Processing Record 24 of Set 15 | ulladulla
# Processing Record 25 of Set 15 | gamba
# Processing Record 26 of Set 15 | farroupilha
# Processing Record 27 of Set 15 | kankaanpaa
# Processing Record 28 of Set 15 | tshikapa
# Processing Record 29 of Set 15 | vaxjo
# Processing Record 30 of Set 15 | teruel
# Processing Record 31 of Set 15 | sorong
# Processing Record 32 of Set 15 | mouzakion
# City not found. Skipping...
# Processing Record 33 of Set 15 | castelo do piaui
# Processing Record 34 of Set 15 | katangli
# Processing Record 35 of Set 15 | tezu
# Processing Record 36 of Set 15 | kloulklubed
# Processing Record 37 of Set 15 | mazeikiai
# Processing Record 38 of Set 15 | lima
# Processing Record 39 of Set 15 | karlstad
# Processing Record 40 of Set 15 | priamurskiy
# Processing Record 41 of Set 15 | morondava
# Processing Record 42 of Set 15 | severo-yeniseyskiy
# Processing Record 43 of Set 15 | mangrol
# Processing Record 44 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 15 | oriximina
# Processing Record 46 of Set 15 | veraval
# Processing Record 47 of Set 15 | mbamba
# Processing Record 48 of Set 15 | anadyr
# Processing Record 49 of Set 15 | moron
# Processing Record 50 of Set 15 | dewa
# Processing Record 1 of Set 16 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 16 | praia da vitoria
# Processing Record 3 of Set 16 | kajaani
# Processing Record 4 of Set 16 | spassk
# Processing Record 5 of Set 16 | baft
# Processing Record 6 of Set 16 | saint-joseph
# Processing Record 7 of Set 16 | lucapa
# Processing Record 8 of Set 16 | santa vitoria do palmar
# Processing Record 9 of Set 16 | sibu
# Processing Record 10 of Set 16 | thinadhoo
# Processing Record 11 of Set 16 | sibolga
# Processing Record 12 of Set 16 | liberia
# Processing Record 13 of Set 16 | bunia
# Processing Record 14 of Set 16 | koygorodok
# Processing Record 15 of Set 16 | teya
# Processing Record 16 of Set 16 | woodward
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 702

# %%
# Add the weather data to a new DataFrame.

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU -33.6500  115.3333     62.92        71          91
# 1          Hilo      US  19.7297 -155.0900     72.25        93          92
# 2     Cape Town      ZA -33.9258   18.4232     76.12        58          20
# 3       Paamiut      GL  61.9940  -49.6678     13.53        73           6
# 4    Shenjiamen      CN  29.9576  122.2980     63.03        65          29
# 5        Dikson      RU  73.5069   80.5464      9.97        92         100
# 6  San Patricio      US  28.0170  -97.5169     77.85        92           0
# 7  Constitucion      CL -35.3333  -72.4167     54.48        80          96
# 8         Vaini      TO -21.2000 -175.2000     71.76        88          20
# 9      Thompson      CA  55.7435  -97.8558      5.16        78         100
#
#    Wind Speed Current Description
# 0       14.29     overcast clouds
# 1        4.00     overcast clouds
# 2       13.80          few clouds
# 3        6.87           clear sky
# 4        8.46    scattered clouds
# 5        8.55     overcast clouds
# 6        7.49           clear sky
# 7        3.65     overcast clouds
# 8        3.44          few clouds
# 9       14.97          light snow

# %%
# Format Lat and Lng columns' decimal separators.
city_data_df["Lat"]=city_data_df["Lat"].map("{:.2f}".format)
city_data_df["Lng"] =city_data_df["Lng"].map("{:.2f}".format)
city_data_df=city_data_df
city_data_df.head(10)
# Out:
#            City Country     Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0     Busselton      AU  -33.65   115.33     62.92        71          91
# 1          Hilo      US   19.73  -155.09     72.25        93          92
# 2     Cape Town      ZA  -33.93    18.42     76.12        58          20
# 3       Paamiut      GL   61.99   -49.67     13.53        73           6
# 4    Shenjiamen      CN   29.96   122.30     63.03        65          29
# 5        Dikson      RU   73.51    80.55      9.97        92         100
# 6  San Patricio      US   28.02   -97.52     77.85        92           0
# 7  Constitucion      CL  -35.33   -72.42     54.48        80          96
# 8         Vaini      TO  -21.20  -175.20     71.76        88          20
# 9      Thompson      CA   55.74   -97.86      5.16        78         100
#
#    Wind Speed Current Description
# 0       14.29     overcast clouds
# 1        4.00     overcast clouds
# 2       13.80          few clouds
# 3        6.87           clear sky
# 4        8.46    scattered clouds
# 5        8.55     overcast clouds
# 6        7.49           clear sky
# 7        3.65     overcast clouds
# 8        3.44          few clouds
# 9       14.97          light snow

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
output_data_file="WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
